# %% [markdown]
# # Imports
#
# Importing necessary packages and modules

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

import random 
import time
from collections import Counter

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from sklearn import random_projection
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import RFE

from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import joblib

import warnings

# %%
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
output_directory = '../resources/model_development_std_medium_remparents'
Path(output_directory).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Objective
#
# The goal of this notebook is to produce then deploy a machine learning model able to forecast that a beginner NBA player is worth investing in because, based on his sports statistics, he will stay in the NBA for more than 5 years. Or not.
#
# Such a model is meant to provide guidance to investors looking to profit on potential NBA talent.
#
# This objective can be formulated as a straightforward classification problem where:
# - Input of the model: Sports statistics of the beginner NBA player.
# - Output of the model: Class of the profile i.e whether it's a profile of a player who would stay in the NBA for more than 5 years ("1") or not ("0"), given input statistics.
# - It's a binary classification problem.
#
# We want to solve the problem by fitting some model to the data samples provided in the assets.

# %%
df = pd.read_csv("./nba_logreg.csv")
print("The dataset we have consists of:")
print("A collection of {} labeled data points.".format(len(df)))
print("Each data point is initially a pair of :")
print("- A a random vector with {} continuous random variables ({}), quantifying each some sport statistic: the predictors.".format(len(df.columns.values), " / ".join(df.columns.values)))
print("- A joint random variable: {}, with {} possible outcomes, telling whether the player is a potential talent (or not): the target.".format("TARGET_5Yrs", len(list(np.unique(df['TARGET_5Yrs'].values)))))
df.head()
# Out:
# The dataset we have consists of:
# A collection of 1340 labeled data points.
# Each data point is initially a pair of :
# - A a random vector with 21 continuous random variables (Name / GP / MIN / PTS / FGM / FGA / FG% / 3P Made / 3PA / 3P% / FTM / FTA / FT% / OREB / DREB / REB / AST / STL / BLK / TOV / TARGET_5Yrs), quantifying each some sport statistic: the predictors.
# - A joint random variable: TARGET_5Yrs, with 2 possible outcomes, telling whether the player is a potential talent (or not): the target.
#               Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
#
#    FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6          0.0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0          0.0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0          1.0
# 4  1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8          1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Formulation of the task as a machine learning problem
#
# We denote data point from the initial dataset presented above by $(x^{(i)},y^{(i)})$, $i=1, 2, .. 1340$, with initially:
# * $x^{(i)} \in \mathbb{R}^{n=19}$: random vector of predictors. A collection of 19 sports statistics about the player.
# * $y^{(i)} \in \{0, 1\}$: random binary target variable with the corresponding player profile's label.
#
# and the whole initial dataset by $D=\{(x^{(i)},y^{(i)})\}_{i=1, .. 1340}$.
#
# The data set we have suggests and allows straightforward learning of many machine learning classification algorithms to solve the task in hand, in a fully supervised fashion.
#
# In practise, we can use a variety of possible classification algorithms and models. Those would have:
# - Different interpretability level
# - Different complexity (in time, in memory)
# - Different performance (in terms of some user-defined metric)
#
# Of course, we want to choose the one that would best fit to our data, adn since it's a binary classification problem, we can evaluate models by their Recall score. Other choices might include: Precision score, F-1 score, etc.
#
# In the following paragraphs, we will investigate more our dataset then try to do efficient learning of some performant classification model leveraging this data. We want to select the model that best fits to our data and that would give the best answer to our binary classification problem in terms of Recall score.

# %% [markdown]
# # Data Sanity Check
#
# But before let's check the sanity of the dataset and whether it needs some more considerations and/or pre-processing before learning from it.

# %% [markdown]
# ## A) Sanity of the predictor variables
#
# First, we check common problems that we might face with the predictor variables.

# %% [markdown]
# ### A.1) Missing values ?
#
# Are there missing values on some predictors ? How to impute such missing values ?

# %%
df.isna().sum()
# Out:
# Name            0
# GP              0
# MIN             0
# PTS             0
# FGM             0
# FGA             0
# FG%             0
# 3P Made         0
# 3PA             0
# 3P%            11
# FTM             0
# FTA             0
# FT%             0
# OREB            0
# DREB            0
# REB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# TARGET_5Yrs     0
# dtype: int64

# %% [markdown]
# Yes, the "3P%" predictor needs more attention. In fact, and as shown above, 11 samples are missing a value for this predictor in our initial dataset.
#
# If we want to not miss those samples in our modelisation, and continue considering them (and thus leverage the information they might carry), we need to impute the missing values they contain with respect to the "3P%" predictor.
#
# Possible values to impute with are:
#
# - Zero.
# - Mean value, by profile type ("1"/"0").
# - Median value, by profile type ("1"/"0").
# - Mean value of the whole "3P%" variable (column).
# - Median value of whole the whole "3P%" column.
# - Etc.

# %%
pd.DataFrame(df['3P%']).boxplot()
print("mean {:.4f} - median {:.4f}".format(df['3P%'].mean(),df['3P%'].median()))
plt.title("Boxplot of {} variable".format("'3P%'"))
plt.show()
# Out:
# mean 19.3081 - median 22.4000

# %% [markdown]
# The boxplot displayed above shows the distribution of observed "3P%" samples.
#
# On average, a beginner NBA player presents a 19.3368 value for this predictor.
#
# Whether the player's profile is considered to be of a talent ("1") or not ("0"), does not really impact its value.
#
# Below we can see that whether the player has a TARGET_5Yrs = "0" or a TARGET_5Yrs = "1" the has nearly the same average value for the "3P%" predictor, 19.4244 and 19.2832 respectively.

# %%
pd.DataFrame(df[df['TARGET_5Yrs'] == 0]['3P%']).boxplot()
print("mean {:.4f} - median {:.4f}".format(df[df['TARGET_5Yrs'] == 0]['3P%'].mean(),df[df['TARGET_5Yrs'] == 0]['3P%'].median()))
plt.title("Boxplot of {}".format("'3P%' given variable 'TARGET_5Yrs' is '0'"))
plt.show()
pd.DataFrame(df[df['TARGET_5Yrs'] == 1]['3P%']).boxplot()
print("mean {:.4f} - median {:.4f}".format(df[df['TARGET_5Yrs'] == 1]['3P%'].mean(),df[df['TARGET_5Yrs'] == 1]['3P%'].median()))
plt.title("Boxplot of {}".format("'3P%' given variable 'TARGET_5Yrs' is '1'"))
plt.show()
# Out:
# mean 19.3781 - median 23.3000
# mean 19.2655 - median 22.2000

# %% [markdown]
# Average "3P%" values per class of profiles were shown to be very close, and very similar to the average of the whole "3P%" column, i.e across all the profiles. The median values are also very comparable.
#
# At this point, we can't make an optimal choice of our strategy for imputing (with which value). Imputing with zero should not be very a good idea considering how "3P%" is distributed: zero is actually an outlier according to the observed distribution of the predictor.
#
# In this work, we choose to work with an arbitrary imputation method.
# We can start by imputing with the mean value, by profile type. And we can later on explore the impact of changing that strategy on the final results.

# %%
def replace_nan(old_val, new_val0, new_val1, cls):
    if cls == 0:
        replace_with = new_val0
    else:
        replace_with = new_val1
    if np.isnan(old_val): return replace_with
    else: return old_val
def do_imputation(df, strategy):
    if strategy == "mean-by-class":
        new_val1 = df[df['TARGET_5Yrs'] == 1]['3P%'].mean()
        new_val0 = df[df['TARGET_5Yrs'] == 0]['3P%'].mean()
    elif strategy == "median-by-class":
        new_val1 = df[df['TARGET_5Yrs'] == 1]['3P%'].median()
        new_val0 = df[df['TARGET_5Yrs'] == 0]['3P%'].median()
    elif strategy == "mean-column":
        new_val1 = df['3P%'].mean()
        new_val0 = new_val1
    elif strategy == "median-column":
        new_val1 = df['3P%'].median()
        new_val0 = new_val1
    else:
        new_val1 = 0.0
        new_val0 = new_val1
    
    df['new_3P%'] = df.apply(lambda x: replace_nan(old_val=x['3P%'], new_val0=new_val0, new_val1=new_val1, cls=int(x['TARGET_5Yrs'])), axis=1)
    df = df.drop('3P%', axis=1)
    df.rename({'new_3P%':'3P%'}, inplace=True, axis=1)
    return df
df = do_imputation(df, strategy="median-by-class")
df.isna().sum()
# Out:
# Name           0
# GP             0
# MIN            0
# PTS            0
# FGM            0
# FGA            0
# FG%            0
# 3P Made        0
# 3PA            0
# FTM            0
# FTA            0
# FT%            0
# OREB           0
# DREB           0
# REB            0
# AST            0
# STL            0
# BLK            0
# TOV            0
# TARGET_5Yrs    0
# 3P%            0
# dtype: int64

# %% [markdown]
# ### A.2) Do predictors values need to be resclaed ?
#
# To answer this question, we need to get a closer look at how our initial set of predictors are distributed and whether they're on the same scale or not.

# %%
df.describe()
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean     60.414179    17.624627     6.801493     2.629104     5.885299
# std      17.433992     8.307964     4.357545     1.683555     3.593488
# min      11.000000     3.100000     0.700000     0.300000     0.800000
# 25%      47.000000    10.875000     3.700000     1.400000     3.300000
# 50%      63.000000    16.100000     5.550000     2.100000     4.800000
# 75%      77.000000    22.900000     8.800000     3.400000     7.500000
# max      82.000000    40.900000    28.200000    10.200000    19.800000
#
#                FG%      3P Made          3PA          FTM          FTA  \
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean     44.169403     0.247612     0.779179     1.297687     1.821940
# std       6.137679     0.383688     1.061847     0.987246     1.322984
# min      23.800000     0.000000     0.000000     0.000000     0.000000
# 25%      40.200000     0.000000     0.000000     0.600000     0.900000
# 50%      44.100000     0.100000     0.300000     1.000000     1.500000
# 75%      47.900000     0.400000     1.200000     1.600000     2.300000
# max      73.700000     2.300000     6.500000     7.700000    10.200000
#
#                FT%         OREB         DREB          REB          AST  \
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean     70.300299     1.009403     2.025746     3.034478     1.550522
# std      10.578479     0.777119     1.360008     2.057774     1.471169
# min       0.000000     0.000000     0.200000     0.300000     0.000000
# 25%      64.700000     0.400000     1.000000     1.500000     0.600000
# 50%      71.250000     0.800000     1.700000     2.500000     1.100000
# 75%      77.600000     1.400000     2.600000     4.000000     2.000000
# max     100.000000     5.300000     9.600000    13.900000    10.600000
#
#                STL          BLK          TOV  TARGET_5Yrs          3P%
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean      0.618507     0.368582     1.193582     0.620149    19.336791
# std       0.409759     0.429049     0.722541     0.485531    15.960156
# min       0.000000     0.000000     0.100000     0.000000     0.000000
# 25%       0.300000     0.100000     0.700000     0.000000     0.000000
# 50%       0.500000     0.200000     1.000000     1.000000    22.400000
# 75%       0.800000     0.500000     1.500000     1.000000    32.500000
# max       2.500000     3.900000     4.400000     1.000000   100.000000

# %%
plt.figure(figsize=(15, 6), dpi=80)
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We clearly observe that not all the variables are on the same scale, and that need to be corrected: Without further considerations that would essentially put all variables to comparable scales without distording their distributions, some variables like "GP", "3P%", "MIN", "FT%", would have more "important" contributions in terms of euclidean distances, compared to other predictors like "FTM", "FTA", "FGM", "STL", "FG%", "BLK", etc. This situation would result in sub-optimal results. In fact: most learning models optimize their objectives based on some euclidiean distances' computation. Some variables might consequently receive more attention than the others, without actually being that important.
#
# To overcome this, we simply need to consider resaling the values of our samples before introducing them as learning inputs to our models.
# The same rescaling process applied on learning data should be reapplied on test data or during inference.
#
# We can use two rescaling techniques:
#
# - Normalization, with: $X_{changed} = \frac{X - X_{min}}{X_{max}-X_{min}}$
#
# - Standard scaling, with: $X_{changed} = \frac{X - \mu}{\sigma}$
#
# In this work, we'll try both techniques before finally picking the one that helps get better performances (with which we obtain the best model).

# %% [markdown]
# ### A.3) Is there redundancy among predictors ?
#
# Aren't some of the predictors correlated between them in some way ? And how to treat that ?

# %% [markdown]
# We can observe, for example, that the predictor variables OREB, DREB and REB are somehow correlated: $REB \sim DERB + OREB$
#
# We can also empirically check that $FT\% \sim \frac{FTM}{FTA}$
#
# Similarly: $FG\% \sim \frac{FGM}{FGA}$
#
# The above observations are confirmed in the boxplots below. Each time we try to superpose the variables in question (eg. REB and OREB + DREB, or FG% and FGM/FGA), and see if the boxplots overlap and to which extent they do. For instance, we can clearly deduce that: REB and OREB are correlated, and that REB and DREB are also correlated.
#
# Following the same reasoning, we can say that FT% and FTA, FT% and FTM, FG% and FGM, FG% and FGA, 3P Marked and 3P%, 3PA and 3P%, are correlated.
#
# We might want to remove this kind of redundancy. In this work, we will try the following strategies and study their impacts on final performances, we'll pick the one for which we obtain the best model:
#
# - No feature is removed.
# - We remove parent-features: FT%, FG%, and 3P%, and we keep FTA, FTM, FGA, FGA, 3P Marked, and 3PA.
# - We remove child-features: FTA, FTM, FGA, FGA, 3P Marked, and 3PA, and we keep FT%, FG%, and 3P%

# %%
pd.DataFrame(df['REB']).boxplot()
pd.DataFrame((df['OREB'] + df['DREB'])).boxplot()
plt.show()
pd.DataFrame(df['FTM']/df['FTA']*100).boxplot()
pd.DataFrame(df['FT%']).boxplot()
plt.show()
pd.DataFrame(df['FGM']/df['FGA']*100).boxplot()
pd.DataFrame(df['FG%']).boxplot()
plt.show()
pd.DataFrame(df['3P Made']/df['3PA']*100).boxplot()
pd.DataFrame(df['3P%']).boxplot()
# Out:
# <AxesSubplot:>

# %%
redundancy_removal_strategy = "remove-parent" #"remove-none", "remove-parent", "remove-child"
if redundancy_removal_strategy == "remove-parent":
    df.drop('REB', axis=1, inplace=True)
    df.drop('3P%', axis=1, inplace=True)
    df.drop('FG%', axis=1, inplace=True)
    df.drop('FT%', axis=1, inplace=True)
elif redundancy_removal_strategy == "remove-child":
    df.drop('OREB', axis=1, inplace=True)
    df.drop('DREB', axis=1, inplace=True)
    df.drop('FTM', axis=1, inplace=True)
    df.drop('FTA', axis=1, inplace=True)
    df.drop('FGM', axis=1, inplace=True)
    df.drop('FGA', axis=1, inplace=True)
    df.drop('3P Made', axis=1, inplace=True)
    df.drop('3PA', axis=1, inplace=True)
else:
    pass
features_names = df.columns.values.tolist()
if 'Name' in features_names: features_names.remove('Name')
if 'TARGET_5Yrs' in features_names: features_names.remove('TARGET_5Yrs')
features_names_file = "predictors.save"
joblib.dump(features_names, output_directory + '/' + features_names_file) 
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## B) What about the target variable ?
#
# Then, we check for problems in the outcome/dependant variable.

# %% [markdown]
# ### B.1) Is there class imbalance ?
#
# As we can see below, the Ratio of imabalance in the initial dataset is: $\frac{\#Samples Class_1}{\#Samples Class_0} = 1.63$ and it's not too high to be considered as a dangerous imbalance signal. But in this work we will try both keeping the dataset as it is, or downsampling majoritary class to remove this light imbalance and study the impact of that on the final results.

# %%
df.hist(column='TARGET_5Yrs')
print("{}/{} ratio.: {:.2f}".format("1","0",float(len(df[df['TARGET_5Yrs']==1])/len(df[df['TARGET_5Yrs']==0]))))
# Out:
# 1/0 ratio.: 1.63

# %% [markdown]
# Here we can control the imbalance ratio, and we can perform downsampling of the majoritary class. In this work, we will try different downsampling ratios before deciding whether it helps in learning, or not.

# %%
def downsample_majoritary(df, ratio):
    maj_df = df[df['TARGET_5Yrs']==1]
    min_df = df[df['TARGET_5Yrs']==0]
    down_maj_df = maj_df.sample(min(int(ratio*len(min_df)),len(maj_df)))
    dff = pd.concat([down_maj_df, min_df], ignore_index=True)
    return dff
df = downsample_majoritary(df, ratio=1.3) #We try setting the ratio to 1. , 1.3, and 1.63
df.hist(column='TARGET_5Yrs')
print("{}/{} ratio.: {:.2f}".format("1","0",float(len(df[df['TARGET_5Yrs']==1])/len(df[df['TARGET_5Yrs']==0]))))
# Out:
# 1/0 ratio.: 1.30

# %% [markdown]
# In all cases, we need to pay attention and make sure that there won't be a poor sampling behavior during split of data leading to introducing some imbalance in actual learning data.

# %% [markdown]
# # Model selection
#
#
# Methodology:
#
# - We start by dividing the dataset into two disjoint sets: A learning set $D_{learn}$ and a testing set $D_{test}$. We make sure that there won't be a poor sampling behavior during split of data leading to introducing some imbalance in actual learning data.
# - Then we normalize $D_{learn}$ and save normalization parameters for later use (on $D_{test}$, or during inference on future examples).
# - We try different classification models, and select the one that performs the best.
# - For that, we use each time a new candidate classification model and learn (train and validate) it on $D_{learn}$ using $k-Fold$ validation technique as a model selection framework.
# - In that case, we need to define which metric is used to assess our model's performance at each validation step. As suggested in the exercise, we can use Recall score as evaluation metric. But in this work we choose to finally assess the performance of the model in terms of f1 macro-averaged score. It's a macro average of f1 measure for both classes. f1 measure for a given class is a harmonic average between Precision and Recall. At constant Precision, a high f1 score means also that the Recall is high. That motivates our choice of the f1 as scoring metric.  The "macro" fashion is more severe (no rebalancing weights are used to weight classes f1 score), and thus gives more severe supervision of the final performance.
# - A validation step on a given fold consists in: Dividing $D_{learn}$ into two disjoint set $D_{train}$ and $D_{valid}$, train the model on $D_{train}$, and scoring it (compute macro-avg f1 score) on $D_{valid}$. A better (higher) "macro" score, means that the score is good for both classes.
# - The validation performance/score of a given model is then computed as the macro-avg f1 score obtained during the k-fold vaidation process.
# - We compare the different models' performances, and select the one with the highest score.
# - Testing set $D_{test}$ will remain hidden during learning process. We will use it later as unseen data to asses the performance of the final selected model, in terms of macro-avg f1 score.

# %% [markdown]
# ## A) Splitting dataset into balanced $D_{learn}$ and  $D_{test}$
#
# We use $85\%$ of the initial samples as learning data (training and validating models). The remaining $15\%$ is kept as unseen data and won't be shown to models during their learning. We'll use it to test the performances of the final model (always in terms of f1 score).
#
# While splitting, we make sure that the both subsets have similar class balance and that we don't introduce imbalance.

# %%
def split_wisely(df, test_percent):
    ones = df[df['TARGET_5Yrs'] == 1]
    zeros = df[df['TARGET_5Yrs'] == 0]
    ones_test_samples_indices = random.sample(range(len(ones)), int(test_percent*len(ones)))
    zeros_test_samples_indices = random.sample(range(len(zeros)), int(test_percent*len(zeros)))
    ones_learn_samples_indices = list(set(range(len(ones))).difference(set(ones_test_samples_indices)))
    zeros_learn_samples_indices = list(set(range(len(zeros))).difference(set(zeros_test_samples_indices)))
    ones_learn_samples = ones.iloc[ones_learn_samples_indices]
    zeros_learn_samples = zeros.iloc[zeros_learn_samples_indices]
    learn_samples = pd.concat([ones_learn_samples, zeros_learn_samples], ignore_index=True)
    ones_test_samples = ones.iloc[ones_test_samples_indices]
    zeros_test_samples = zeros.iloc[zeros_test_samples_indices]
    test_samples = pd.concat([ones_test_samples, zeros_test_samples], ignore_index=True)
    return learn_samples, test_samples
learn_df, test_df = split_wisely(df, test_percent=0.15)
print(len(df))
print("Learn df - size:", len(learn_df))
print("Test df - size:", len(test_df))
print("Learn df - class imbalance ratio:", len(learn_df[learn_df['TARGET_5Yrs']==1])/len(learn_df[learn_df['TARGET_5Yrs']==0]))
print("Test df - class imbalance ratio:", len(test_df[test_df['TARGET_5Yrs']==1])/len(test_df[test_df['TARGET_5Yrs']==0]))
print("Learn df - contains nans:", learn_df.isnull().values.any())
print("Test df - contains nans:", test_df.isnull().values.any())
Xlearn = learn_df.drop(['Name', 'TARGET_5Yrs'], axis=1)
Ylearn = learn_df['TARGET_5Yrs']
Xtest = test_df.drop(['Name', 'TARGET_5Yrs'], axis=1)
Ytest = test_df['TARGET_5Yrs']
# Out:
# 1170
# Learn df - size: 995
# Test df - size: 175
# Learn df - class imbalance ratio: 1.297921478060046
# Test df - class imbalance ratio: 1.3026315789473684
# Learn df - contains nans: False
# Test df - contains nans: False

# %% [markdown]
# ## B) Normalizing learning data and saving the parameters
#
# As shown above, our predictors need to be normalized/ rescaled.

# %% [markdown]
# ### B.1) Computing normalizer on $D_{learn}$, and saving its params
#
# We compute the rescaling/normalization parameters exclusively from learning data, i.e $D_{learn}$ as if it was the only data set we have during the development of our models. Then we save those parameters, and re-apply the same rescaling procedure on any future data points (c.f samples from $D_{test}$ or any other future (new) unseen sample).

# %%
#normalizer = MinMaxScaler()
normalizer = StandardScaler()
normalizer.fit(Xlearn.to_numpy())
normalizer_filename = "normalizer.save"
joblib.dump(normalizer, output_directory + '/' + normalizer_filename)
# Out:
# ['../resources/model_development_std_medium_remparents/normalizer.save']

# %% [markdown]
# ### B.2) Reloading the normalizer, and actual transformation of $D_{learn}$
#
# We perform actual transformation of $D_{learn}$ using the pre-computed normalizer. The normalized version of the data, $D_{learn_{Normalized}}$ is the one we use to train the classifiers.

# %%
normalizer = joblib.load(output_directory + '/' + normalizer_filename) 
Xlearn_normalized = normalizer.transform(Xlearn)

# %% [markdown]
# ## C) Definition of dimensionailty reduction methods
#
# Out of the 19 initial predictors present in our - normalized - dataset, we can choose to keep 15 or less (depedning on redundancy removal strategy) of them after removing redundant ones (cf. previous paragraphs).
# We might want to reduce a bit more the dimensionality of our data for many reasons (avoid dimensionalirty curse, better and more informative features, faster learning) either by projecting them into completely new features spaces, or by ranking and extracting most important features in the initial predictors' space. Possible methods we can use are:
#
# - Principal Components Analysis, Random Projections, etc.
# - Eliminate variables with low variance, Recursive features extraction, etc.
#
# Below is the code that handles features selection possibility before entering the actual validation loop.

# %%
def do_pca(X, y, k):
    transformer_instance = PCA(random_state=1, n_components=k)
    X_new = transformer_instance.fit_transform(X)
    return X_new, transformer_instance

def do_rp(X, y, k):
    transformer_instance = random_projection.GaussianRandomProjection(random_state=1, n_components=k)
    X_new = transformer_instance.fit_transform(X)
    return X_new, transformer_instance

def do_rlvf(X, y, t):
    transofrmer_instance = VarianceThreshold(threshold=t)
    X_new = transofrmer_instance.fit_transform(X)
    return X_new, transofrmer_instance

def do_rfe(X, y, k):
    transformer_instance = RFE(estimator=SVC(random_state=1, kernel="linear", C=1), n_features_to_select=k, step=1)
    X_new = transformer_instance.fit_transform(X, y)
    return X_new, transformer_instance

def handle_feature_selection(Xlearn_normalized, Ylearn, selection_option, k, t):
    X = Xlearn_normalized
    nb_features = X.shape[1]
    y = Ylearn
    if selection_option == "pca":
        return do_pca(X, None, min(k, nb_features))
    elif selection_option == "random-projection":
        return do_rp(X, None, min(k, nb_features))
    elif selection_option == "recursive-feature-extraction":
        return do_rfe(X, y, min(k, nb_features))
    elif selection_option == "remove-low-var-features":
        return do_rlvf(X, None, t)
    else:
        return Xlearn_normalized, None

# %% [markdown]
# ## D) Definition of candidate models' architectures
#
# Given the same data set, normalized and possibly transformed as stated in the previous dim. reduction step, we choose to rank different classification models based on their validation scores and following the protocole described above. We start by a Baseline (Naive bayes) classifier, and we add some linear models (what if data points are linearly separable): An SVM with linear kernel, a logistic regression model, etc. And other non-linear ones (otherwise): SVM with non-linear kernels, Decision Tree, Random Forest, Multi layer perceptron, etc. We want to select the best one, i.e the one that has the highest final validation score.

# %%
candidate_models = {
    "BASELINES": [
        {"NB": GaussianNB()},
    ], 
    "LINEAR-MODELS": [
        {"SVM-l2": LinearSVC(penalty="l2", random_state=1)},
        {"LR-l2": LogisticRegression(penalty="l2", random_state=1)},
    ], 
    "NON-LINEAR-MODELS":[
        {"SVM-rbf": SVC(random_state=1, C=1, kernel="rbf")}, 
        {"SVM-poly": SVC(random_state=1, C=1, kernel="poly", degree=4)},
        {"DT-gini": DecisionTreeClassifier(random_state=1, criterion='gini')},
        {"DT-entropy": DecisionTreeClassifier(random_state=1, criterion='entropy')},
        {"RF-100-gini": RandomForestClassifier(n_estimators=100, criterion="gini", random_state=1)},
        {"RF-100-entropy": RandomForestClassifier(n_estimators=100, criterion="entropy", random_state=1)},
        {"RF-250-gini": RandomForestClassifier(n_estimators=250, criterion="gini", random_state=1)},
        {"RF-250-entropy": RandomForestClassifier(n_estimators=250, criterion="entropy", random_state=1)},
        {"MLP-64": MLPClassifier(random_state=1, hidden_layer_sizes=(64, 64), activation='relu', max_iter=1000)},
        {"MLP-128": MLPClassifier(random_state=1, hidden_layer_sizes=(128, 128), activation='relu', max_iter=1000)},
    ], 
    }

# %% [markdown]
# ## E) Definition of models' scoring method
#
# A given candidate classifier from the above list is scored using the macro average f1 score, computed on validation folds during a k-Fold learning (training and validation) process. Please note that the learning of all the models should be done using the same $D_{learn}$ set, and following the same pre-processing (normalization, then optionnally dimensionality reduction) pipeline in each case.

# %%
def score_classifier(X, y, model):
    kf = KFold(n_splits=4,random_state=1,shuffle=True)
    confusion_mat = np.zeros((2,2))
    f1_valid_score = 0.0
    recall_valid_score = 0.0
    for training_ids, test_ids in kf.split(X):
        training_set = X[training_ids]
        training_labels = y[training_ids]
        test_set = X[test_ids]
        test_labels = y[test_ids]
        model.fit(training_set,training_labels)
        predicted_labels = model.predict(test_set)
        confusion_mat += confusion_matrix(test_labels,predicted_labels)
        recall_valid_score += recall_score(test_labels, predicted_labels, average="macro")
        f1_valid_score += f1_score(test_labels, predicted_labels, average="macro")
    recall_valid_score /= 3
    f1_valid_score /= 3
    return confusion_mat, f1_valid_score, recall_valid_score

# %% [markdown]
# ## F) Model selection
#
# At this level, we put everything together: each candidate model, preceeded or not by a feature selection method, is trained and validated on $D_{learn}$ using the k-Fold validation technique. The score (average score over validation folds) for each model is finally saved along with the learning results.

# %% [markdown]
# ### F.1) Candidate models scoring loop
#
# Here we perform the scoring, looping through all candidate classfiers, training them on $D^{fold}_{train} \subset D_{learn}$, and computing macro-avg f1 score over $D^{fold}_{valid} \subset D_{learn}$ as measure of performance of the candidate model. With: $D_{learn} = D^{fold}_{train} \cup D^{fold}_{valid}$

# %%
ks = [3, 6, 9, 12, 15]
ts = [.025, .05]
selection_options = ["no-selection", "pca", "random-projection", "recursive-feature-extraction", "remove-low-var-features"]
history = []
for t in ts:
    for k in ks:
        for model_family, family_candidates in candidate_models.items():
            for candidate_model in family_candidates:
                model_name = list(candidate_model.keys())[0]
                model_instance = list(candidate_model.values())[0]
                for selection_option in selection_options:
                    learn_time = time.time()
                    Xlearn_featurized, transformer = handle_feature_selection(Xlearn_normalized, Ylearn, selection_option, k, t)
                    confusion_mat, f1score, recall = score_classifier(Xlearn_featurized, Ylearn, model_instance)
                    learn_time = time.time() - learn_time
                    print("{} - model name: {} - selection option: {}".format(model_family, model_name, selection_option))
                    print("performance: f1score {} - recall {} - Confusion matrix {}\n".format(f1score, recall, confusion_mat))
                    config_and_result = {"family":model_family, "name":model_name, "select_option":selection_option, "f1-score":f1score, "recall":recall, "confusion":confusion_mat, "k":k, "t":t, "learn_time":learn_time, "transformer":transformer}
                    history.append(config_and_result)
# Out:
# BASELINES - model name: NB - selection option: no-selection
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# BASELINES - model name: NB - selection option: pca
# performance: f1score 0.8554726529537063 - recall 0.8774244486888166 - Confusion matrix [[336.  97.]
#  [258. 304.]]
#
# BASELINES - model name: NB - selection option: random-projection
# performance: f1score 0.8304514695729264 - recall 0.8372981424705562 - Confusion matrix [[283. 150.]
#  [224. 338.]]
#
# BASELINES - model name: NB - selection option: recursive-feature-extraction
# performance: f1score 0.8908054118739855 - recall 0.8899278031461938 - Confusion matrix [[261. 172.]
#  [150. 412.]]
#
# BASELINES - model name: NB - selection option: remove-low-var-features
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: no-selection
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: pca
# performance: f1score 0.89680844696956 - recall 0.9001461501461501 - Confusion matrix [[285. 148.]
#  [173. 389.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: random-projection
# performance: f1score 0.7311897446954086 - recall 0.751881372139993 - Confusion matrix [[137. 296.]
#  [107. 455.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.8908275155467692 - recall 0.8894514064054295 - Confusion matrix [[240. 193.]
#  [124. 438.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: remove-low-var-features
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: no-selection
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: pca
# performance: f1score 0.8971721302361058 - recall 0.8997614879798789 - Confusion matrix [[281. 152.]
#  [168. 394.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: random-projection
# performance: f1score 0.7300528061910847 - recall 0.7498631051791972 - Confusion matrix [[138. 295.]
#  [110. 452.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.8927149383963736 - recall 0.8913884008711596 - Confusion matrix [[242. 191.]
#  [125. 437.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: remove-low-var-features
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: no-selection
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: pca
# performance: f1score 0.8962089467307143 - recall 0.8998558274420342 - Confusion matrix [[282. 151.]
#  [170. 392.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: random-projection
# performance: f1score 0.8428601865583746 - recall 0.8432353247008418 - Confusion matrix [[216. 217.]
#  [132. 430.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: recursive-feature-extraction
# performance: f1score 0.8905089440319919 - recall 0.8913081331184779 - Confusion matrix [[266. 167.]
#  [157. 405.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: remove-low-var-features
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: no-selection
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: pca
# performance: f1score 0.4833669260946691 - recall 0.6657978249932274 - Confusion matrix [[  1. 432.]
#  [  2. 560.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: random-projection
# performance: f1score 0.4937761439178703 - recall 0.6618044152526911 - Confusion matrix [[  6. 427.]
#  [ 12. 550.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: recursive-feature-extraction
# performance: f1score 0.6017655044260665 - recall 0.7188877640027066 - Confusion matrix [[ 41. 392.]
#  [  9. 553.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: remove-low-var-features
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: no-selection
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: pca
# performance: f1score 0.7666464307177311 - recall 0.7686237985088559 - Confusion matrix [[224. 209.]
#  [206. 356.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: random-projection
# performance: f1score 0.7273455834400187 - recall 0.7282199973291927 - Confusion matrix [[222. 211.]
#  [235. 327.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: recursive-feature-extraction
# performance: f1score 0.7828262537275984 - recall 0.7858698559847985 - Confusion matrix [[249. 184.]
#  [223. 339.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: remove-low-var-features
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: no-selection
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: pca
# performance: f1score 0.7613281852773656 - recall 0.763764827126896 - Confusion matrix [[226. 207.]
#  [213. 349.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: random-projection
# performance: f1score 0.7572473062204014 - recall 0.7573924479096893 - Confusion matrix [[222. 211.]
#  [210. 352.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8069533290365495 - recall 0.8095916269766845 - Confusion matrix [[256. 177.]
#  [212. 350.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: remove-low-var-features
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: no-selection
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: pca
# performance: f1score 0.8099826625771644 - recall 0.8116291328935006 - Confusion matrix [[234. 199.]
#  [183. 379.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: random-projection
# performance: f1score 0.804759187293827 - recall 0.8054738630888055 - Confusion matrix [[214. 219.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8554436562641561 - recall 0.8552229911425314 - Confusion matrix [[247. 186.]
#  [162. 400.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: remove-low-var-features
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: no-selection
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: pca
# performance: f1score 0.8264519011466579 - recall 0.8276944904818467 - Confusion matrix [[240. 193.]
#  [177. 385.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: random-projection
# performance: f1score 0.7784511248168003 - recall 0.7796898716438947 - Confusion matrix [[202. 231.]
#  [167. 395.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8551050722877557 - recall 0.8550020435077906 - Confusion matrix [[250. 183.]
#  [166. 396.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: remove-low-var-features
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: no-selection
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: pca
# performance: f1score 0.8210897723359699 - recall 0.8219417980912235 - Confusion matrix [[234. 199.]
#  [174. 388.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: random-projection
# performance: f1score 0.7921796457357697 - recall 0.7931956559830123 - Confusion matrix [[209. 224.]
#  [165. 397.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8572784594365164 - recall 0.8567643084884464 - Confusion matrix [[245. 188.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: remove-low-var-features
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: no-selection
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: pca
# performance: f1score 0.8186291375435809 - recall 0.8197564834059087 - Confusion matrix [[235. 198.]
#  [177. 385.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: random-projection
# performance: f1score 0.7924449781781493 - recall 0.7933915169547353 - Confusion matrix [[208. 225.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8555087595310784 - recall 0.8552119761889877 - Confusion matrix [[247. 186.]
#  [162. 400.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: remove-low-var-features
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: no-selection
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: pca
# performance: f1score 0.8264059892631304 - recall 0.8274577434060193 - Confusion matrix [[233. 200.]
#  [168. 394.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: random-projection
# performance: f1score 0.783540400843508 - recall 0.7843557836373929 - Confusion matrix [[204. 229.]
#  [165. 397.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: recursive-feature-extraction
# performance: f1score 0.880583932388785 - recall 0.883213157638445 - Confusion matrix [[263. 170.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: remove-low-var-features
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: no-selection
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: pca
# performance: f1score 0.837035409560765 - recall 0.8399537138042886 - Confusion matrix [[252. 181.]
#  [183. 379.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: random-projection
# performance: f1score 0.8020790813446421 - recall 0.8034750370957268 - Confusion matrix [[239. 194.]
#  [194. 368.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: recursive-feature-extraction
# performance: f1score 0.8726540544599164 - recall 0.875662406984246 - Confusion matrix [[256. 177.]
#  [159. 403.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: remove-low-var-features
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# BASELINES - model name: NB - selection option: no-selection
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# BASELINES - model name: NB - selection option: pca
# performance: f1score 0.8709963503564658 - recall 0.882019241933035 - Confusion matrix [[313. 120.]
#  [223. 339.]]
#
# BASELINES - model name: NB - selection option: random-projection
# performance: f1score 0.7803117620874879 - recall 0.815048563611782 - Confusion matrix [[337.  96.]
#  [311. 251.]]
#
# BASELINES - model name: NB - selection option: recursive-feature-extraction
# performance: f1score 0.8702689486490701 - recall 0.8918003505647184 - Confusion matrix [[341.  92.]
#  [252. 310.]]
#
# BASELINES - model name: NB - selection option: remove-low-var-features
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: no-selection
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: pca
# performance: f1score 0.9197495157741457 - recall 0.9188994009396309 - Confusion matrix [[272. 161.]
#  [139. 423.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: random-projection
# performance: f1score 0.9029294583133547 - recall 0.9027781392723923 - Confusion matrix [[271. 162.]
#  [152. 410.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9175560561751643 - recall 0.9163465525534491 - Confusion matrix [[265. 168.]
#  [133. 429.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: remove-low-var-features
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: no-selection
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: pca
# performance: f1score 0.9257979617258097 - recall 0.9253601124290779 - Confusion matrix [[277. 156.]
#  [140. 422.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: random-projection
# performance: f1score 0.9018276809726554 - recall 0.901359368600748 - Confusion matrix [[268. 165.]
#  [149. 413.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9242036216819963 - recall 0.9229244148784379 - Confusion matrix [[268. 165.]
#  [131. 431.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: remove-low-var-features
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: no-selection
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: pca
# performance: f1score 0.906559863678076 - recall 0.9075184181506021 - Confusion matrix [[277. 156.]
#  [156. 406.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: random-projection
# performance: f1score 0.8723803973159949 - recall 0.8730143153993729 - Confusion matrix [[260. 173.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: recursive-feature-extraction
# performance: f1score 0.9109092762954005 - recall 0.9112334185610048 - Confusion matrix [[278. 155.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: remove-low-var-features
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: no-selection
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: pca
# performance: f1score 0.5674422171240333 - recall 0.6834145739318154 - Confusion matrix [[ 35. 398.]
#  [ 31. 531.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: random-projection
# performance: f1score 0.5137920449633885 - recall 0.6644597739425325 - Confusion matrix [[ 14. 419.]
#  [ 20. 542.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: recursive-feature-extraction
# performance: f1score 0.6266622879373411 - recall 0.7171954801265145 - Confusion matrix [[ 57. 376.]
#  [ 31. 531.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: remove-low-var-features
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: no-selection
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: pca
# performance: f1score 0.7696657815775275 - recall 0.770803393073508 - Confusion matrix [[234. 199.]
#  [216. 346.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: random-projection
# performance: f1score 0.7101914382493163 - recall 0.7120576688105423 - Confusion matrix [[194. 239.]
#  [215. 347.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: recursive-feature-extraction
# performance: f1score 0.7647318894416317 - recall 0.7649960139902668 - Confusion matrix [[217. 216.]
#  [199. 363.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: remove-low-var-features
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: no-selection
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: pca
# performance: f1score 0.7317416172212138 - recall 0.7327638410971744 - Confusion matrix [[222. 211.]
#  [232. 330.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: random-projection
# performance: f1score 0.759174691447964 - recall 0.7604139155863295 - Confusion matrix [[209. 224.]
#  [193. 369.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.7776557346988643 - recall 0.7775524656271783 - Confusion matrix [[225. 208.]
#  [198. 364.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: remove-low-var-features
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: no-selection
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: pca
# performance: f1score 0.8479057238317194 - recall 0.8475561209756611 - Confusion matrix [[245. 188.]
#  [165. 397.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: random-projection
# performance: f1score 0.8041511213176521 - recall 0.8038427090151229 - Confusion matrix [[221. 212.]
#  [171. 391.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8426658224693276 - recall 0.8419676428297117 - Confusion matrix [[238. 195.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: remove-low-var-features
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: no-selection
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: pca
# performance: f1score 0.8636958192151307 - recall 0.8633790592123926 - Confusion matrix [[252. 181.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: random-projection
# performance: f1score 0.7949519846217656 - recall 0.7947464466142627 - Confusion matrix [[222. 211.]
#  [180. 382.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8336945081848036 - recall 0.8332267774796511 - Confusion matrix [[240. 193.]
#  [171. 391.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: remove-low-var-features
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: no-selection
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: pca
# performance: f1score 0.855436470387256 - recall 0.8548422256755591 - Confusion matrix [[244. 189.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: random-projection
# performance: f1score 0.7978839021580959 - recall 0.7978690796219531 - Confusion matrix [[217. 216.]
#  [171. 391.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8415699014834059 - recall 0.8411926462213818 - Confusion matrix [[238. 195.]
#  [162. 400.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: remove-low-var-features
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: no-selection
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: pca
# performance: f1score 0.8559532164308677 - recall 0.8556546582408652 - Confusion matrix [[247. 186.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: random-projection
# performance: f1score 0.7917968596906378 - recall 0.7920066364031881 - Confusion matrix [[216. 217.]
#  [175. 387.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8270836323249915 - recall 0.8268052828397656 - Confusion matrix [[238. 195.]
#  [174. 388.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: remove-low-var-features
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: no-selection
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: pca
# performance: f1score 0.7962445339673532 - recall 0.7970843332912297 - Confusion matrix [[225. 208.]
#  [182. 380.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: random-projection
# performance: f1score 0.7578824881596002 - recall 0.7589367688505618 - Confusion matrix [[229. 204.]
#  [219. 343.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: recursive-feature-extraction
# performance: f1score 0.8393403829572189 - recall 0.8423452452188084 - Confusion matrix [[247. 186.]
#  [175. 387.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: remove-low-var-features
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: no-selection
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: pca
# performance: f1score 0.7840174904200902 - recall 0.7880217217860896 - Confusion matrix [[232. 201.]
#  [198. 364.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: random-projection
# performance: f1score 0.7676736249539028 - recall 0.7700491824055042 - Confusion matrix [[216. 217.]
#  [195. 367.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: recursive-feature-extraction
# performance: f1score 0.8312038678615012 - recall 0.833568884287275 - Confusion matrix [[257. 176.]
#  [194. 368.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: remove-low-var-features
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# BASELINES - model name: NB - selection option: no-selection
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# BASELINES - model name: NB - selection option: pca
# performance: f1score 0.8501785653353848 - recall 0.8675856497695578 - Confusion matrix [[323. 110.]
#  [249. 313.]]
#
# BASELINES - model name: NB - selection option: random-projection
# performance: f1score 0.8023485504782095 - recall 0.8353268963901147 - Confusion matrix [[342.  91.]
#  [301. 261.]]
#
# BASELINES - model name: NB - selection option: recursive-feature-extraction
# performance: f1score 0.8651543083456108 - recall 0.8924434547997766 - Confusion matrix [[351.  82.]
#  [265. 297.]]
#
# BASELINES - model name: NB - selection option: remove-low-var-features
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: no-selection
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: pca
# performance: f1score 0.9142797522498837 - recall 0.913255241990874 - Confusion matrix [[268. 165.]
#  [139. 423.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: random-projection
# performance: f1score 0.9009231294970682 - recall 0.8999788047201841 - Confusion matrix [[265. 168.]
#  [146. 416.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9131856494627911 - recall 0.9121348000658346 - Confusion matrix [[267. 166.]
#  [139. 423.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: remove-low-var-features
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: no-selection
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: pca
# performance: f1score 0.915136100054602 - recall 0.9144010523320869 - Confusion matrix [[271. 162.]
#  [142. 420.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: random-projection
# performance: f1score 0.9077204016079413 - recall 0.9067526981320085 - Confusion matrix [[267. 166.]
#  [143. 419.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9187736448437107 - recall 0.9177412997815297 - Confusion matrix [[270. 163.]
#  [138. 424.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: remove-low-var-features
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: no-selection
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: pca
# performance: f1score 0.9077222043585197 - recall 0.9084693616302811 - Confusion matrix [[276. 157.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: random-projection
# performance: f1score 0.8881019512853333 - recall 0.8888391355345377 - Confusion matrix [[271. 162.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: recursive-feature-extraction
# performance: f1score 0.9095858588580003 - recall 0.9102034300310162 - Confusion matrix [[277. 156.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: remove-low-var-features
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: no-selection
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: pca
# performance: f1score 0.5908875528792484 - recall 0.6902607875309025 - Confusion matrix [[ 46. 387.]
#  [ 40. 522.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: random-projection
# performance: f1score 0.5270179132383503 - recall 0.6646533543085268 - Confusion matrix [[ 20. 413.]
#  [ 28. 534.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: recursive-feature-extraction
# performance: f1score 0.6292517705928369 - recall 0.7142129156496972 - Confusion matrix [[ 60. 373.]
#  [ 38. 524.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: remove-low-var-features
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: no-selection
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: pca
# performance: f1score 0.7633061092897689 - recall 0.7647057603954156 - Confusion matrix [[228. 205.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: random-projection
# performance: f1score 0.7338195100102544 - recall 0.7346370370795658 - Confusion matrix [[215. 218.]
#  [222. 340.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: recursive-feature-extraction
# performance: f1score 0.7721226214157982 - recall 0.7728776225902664 - Confusion matrix [[235. 198.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: remove-low-var-features
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: no-selection
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: pca
# performance: f1score 0.7745354125296217 - recall 0.7759660358798289 - Confusion matrix [[234. 199.]
#  [212. 350.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: random-projection
# performance: f1score 0.7274957067479818 - recall 0.7282267806693093 - Confusion matrix [[211. 222.]
#  [222. 340.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.7696954048577952 - recall 0.7701774226199514 - Confusion matrix [[230. 203.]
#  [211. 351.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: remove-low-var-features
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: no-selection
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: pca
# performance: f1score 0.8653429362266332 - recall 0.8641830338669418 - Confusion matrix [[242. 191.]
#  [147. 415.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: random-projection
# performance: f1score 0.8158950095434889 - recall 0.8158629152882027 - Confusion matrix [[233. 200.]
#  [177. 385.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8540763039380921 - recall 0.8535644219552264 - Confusion matrix [[248. 185.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: remove-low-var-features
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: no-selection
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: pca
# performance: f1score 0.8689504014511659 - recall 0.8681833013729566 - Confusion matrix [[250. 183.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: random-projection
# performance: f1score 0.8267796124855677 - recall 0.8264601299084058 - Confusion matrix [[241. 192.]
#  [177. 385.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8707509064611657 - recall 0.8700988825988826 - Confusion matrix [[257. 176.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: remove-low-var-features
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: no-selection
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: pca
# performance: f1score 0.8606706093295347 - recall 0.8596723944425092 - Confusion matrix [[243. 190.]
#  [152. 410.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: random-projection
# performance: f1score 0.8173927218080862 - recall 0.8173595667848542 - Confusion matrix [[234. 199.]
#  [177. 385.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8644939426418686 - recall 0.8639650898271588 - Confusion matrix [[255. 178.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: remove-low-var-features
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: no-selection
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: pca
# performance: f1score 0.8567646951418452 - recall 0.855857089908814 - Confusion matrix [[246. 187.]
#  [159. 403.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: random-projection
# performance: f1score 0.8262554215109706 - recall 0.8258691393748866 - Confusion matrix [[237. 196.]
#  [173. 389.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8764977671824119 - recall 0.8756352789398766 - Confusion matrix [[255. 178.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: remove-low-var-features
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: no-selection
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: pca
# performance: f1score 0.7896003559768076 - recall 0.7901847832882316 - Confusion matrix [[233. 200.]
#  [198. 364.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: random-projection
# performance: f1score 0.7676937577108559 - recall 0.7681794578346303 - Confusion matrix [[228. 205.]
#  [210. 352.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: recursive-feature-extraction
# performance: f1score 0.8022847528569715 - recall 0.8027624355210561 - Confusion matrix [[228. 205.]
#  [182. 380.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: remove-low-var-features
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: no-selection
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: pca
# performance: f1score 0.8089194598885433 - recall 0.8108505744999999 - Confusion matrix [[244. 189.]
#  [195. 367.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: random-projection
# performance: f1score 0.7918155263650482 - recall 0.7952418005578924 - Confusion matrix [[254. 179.]
#  [222. 340.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: recursive-feature-extraction
# performance: f1score 0.8380505321886978 - recall 0.8385776154454315 - Confusion matrix [[249. 184.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: remove-low-var-features
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# BASELINES - model name: NB - selection option: no-selection
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# BASELINES - model name: NB - selection option: pca
# performance: f1score 0.8433896336104122 - recall 0.8603072799911881 - Confusion matrix [[319. 114.]
#  [250. 312.]]
#
# BASELINES - model name: NB - selection option: random-projection
# performance: f1score 0.8229348303071369 - recall 0.8554321264091379 - Confusion matrix [[348.  85.]
#  [292. 270.]]
#
# BASELINES - model name: NB - selection option: recursive-feature-extraction
# performance: f1score 0.8554928066366999 - recall 0.8829152435474276 - Confusion matrix [[349.  84.]
#  [270. 292.]]
#
# BASELINES - model name: NB - selection option: remove-low-var-features
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: no-selection
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: pca
# performance: f1score 0.9149170225255889 - recall 0.9137912109176476 - Confusion matrix [[268. 165.]
#  [139. 423.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: random-projection
# performance: f1score 0.9200828741333259 - recall 0.9184563254965553 - Confusion matrix [[265. 168.]
#  [131. 431.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.917630151530398 - recall 0.9167306671617017 - Confusion matrix [[270. 163.]
#  [139. 423.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: remove-low-var-features
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: no-selection
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: pca
# performance: f1score 0.9267420886632776 - recall 0.9253961024075966 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: random-projection
# performance: f1score 0.927709494613406 - recall 0.9263598417334049 - Confusion matrix [[271. 162.]
#  [132. 430.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9218196211509316 - recall 0.9208815662838651 - Confusion matrix [[272. 161.]
#  [138. 424.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: remove-low-var-features
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: no-selection
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: pca
# performance: f1score 0.9077367107246079 - recall 0.908253639719157 - Confusion matrix [[275. 158.]
#  [153. 409.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: random-projection
# performance: f1score 0.8847995060122047 - recall 0.8852025635071611 - Confusion matrix [[267. 166.]
#  [162. 400.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: recursive-feature-extraction
# performance: f1score 0.9107701686436301 - recall 0.9116245397854593 - Confusion matrix [[279. 154.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: remove-low-var-features
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: no-selection
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: pca
# performance: f1score 0.5998284061691267 - recall 0.6964160520195003 - Confusion matrix [[ 49. 384.]
#  [ 39. 523.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: random-projection
# performance: f1score 0.5427116179925472 - recall 0.6706807879221673 - Confusion matrix [[ 26. 407.]
#  [ 31. 531.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: recursive-feature-extraction
# performance: f1score 0.6264908965119343 - recall 0.7147107203141685 - Confusion matrix [[ 58. 375.]
#  [ 35. 527.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: remove-low-var-features
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: no-selection
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: pca
# performance: f1score 0.7602998584597117 - recall 0.7622151581921698 - Confusion matrix [[238. 195.]
#  [228. 334.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: random-projection
# performance: f1score 0.7405734683198534 - recall 0.7411889727981681 - Confusion matrix [[217. 216.]
#  [219. 343.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: recursive-feature-extraction
# performance: f1score 0.7557118607990198 - recall 0.7587794549001444 - Confusion matrix [[240. 193.]
#  [234. 328.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: remove-low-var-features
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: no-selection
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: pca
# performance: f1score 0.7610186451868742 - recall 0.7629488221442244 - Confusion matrix [[234. 199.]
#  [222. 340.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: random-projection
# performance: f1score 0.7672010921236261 - recall 0.7671943584299906 - Confusion matrix [[222. 211.]
#  [203. 359.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.7274562306855806 - recall 0.7285963025905554 - Confusion matrix [[208. 225.]
#  [217. 345.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: remove-low-var-features
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: no-selection
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: pca
# performance: f1score 0.8721542605791813 - recall 0.8709975847906882 - Confusion matrix [[237. 196.]
#  [135. 427.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: random-projection
# performance: f1score 0.8679578255688978 - recall 0.8676869852157209 - Confusion matrix [[248. 185.]
#  [153. 409.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: recursive-feature-extraction
# performance: f1score 0.852897330044588 - recall 0.8523177014556325 - Confusion matrix [[243. 190.]
#  [159. 403.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: remove-low-var-features
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: no-selection
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: pca
# performance: f1score 0.8599469458269473 - recall 0.8591553880346984 - Confusion matrix [[236. 197.]
#  [144. 418.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: random-projection
# performance: f1score 0.8546838016176777 - recall 0.854198005060074 - Confusion matrix [[245. 188.]
#  [160. 402.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8631010786565616 - recall 0.8627860219814242 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: remove-low-var-features
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: no-selection
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: pca
# performance: f1score 0.8847045029541564 - recall 0.8833056045699724 - Confusion matrix [[244. 189.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: random-projection
# performance: f1score 0.8668102796242619 - recall 0.866282902920834 - Confusion matrix [[248. 185.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8654999015485473 - recall 0.8647329097041739 - Confusion matrix [[249. 184.]
#  [156. 406.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: remove-low-var-features
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: no-selection
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: pca
# performance: f1score 0.8912107036355268 - recall 0.8895973758042723 - Confusion matrix [[246. 187.]
#  [131. 431.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: random-projection
# performance: f1score 0.871393900652079 - recall 0.8708759259046616 - Confusion matrix [[251. 182.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8628107421856753 - recall 0.8622555605314227 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: remove-low-var-features
# ...
# performance: f1score 0.8668102796242619 - recall 0.866282902920834 - Confusion matrix [[248. 185.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8654999015485473 - recall 0.8647329097041739 - Confusion matrix [[249. 184.]
#  [156. 406.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: remove-low-var-features
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: no-selection
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: pca
# performance: f1score 0.8912107036355268 - recall 0.8895973758042723 - Confusion matrix [[246. 187.]
#  [131. 431.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: random-projection
# performance: f1score 0.871393900652079 - recall 0.8708759259046616 - Confusion matrix [[251. 182.]
#  [154. 408.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8628107421856753 - recall 0.8622555605314227 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: remove-low-var-features
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: no-selection
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: pca
# performance: f1score 0.8204311185093672 - recall 0.8214654119826533 - Confusion matrix [[250. 183.]
#  [194. 368.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: random-projection
# performance: f1score 0.8214610868698974 - recall 0.821504410872227 - Confusion matrix [[246. 187.]
#  [188. 374.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: recursive-feature-extraction
# performance: f1score 0.8114901650797224 - recall 0.8119755723204 - Confusion matrix [[239. 194.]
#  [188. 374.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: remove-low-var-features
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: no-selection
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: pca
# performance: f1score 0.8317427102930454 - recall 0.8333816938701997 - Confusion matrix [[251. 182.]
#  [186. 376.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: random-projection
# performance: f1score 0.8220095672533736 - recall 0.8221188613429993 - Confusion matrix [[231. 202.]
#  [169. 393.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: recursive-feature-extraction
# performance: f1score 0.8271411444654678 - recall 0.8290862128505806 - Confusion matrix [[245. 188.]
#  [182. 380.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: remove-low-var-features
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# BASELINES - model name: NB - selection option: no-selection
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# BASELINES - model name: NB - selection option: pca
# performance: f1score 0.8444541210470895 - recall 0.862999691879002 - Confusion matrix [[322. 111.]
#  [252. 310.]]
#
# BASELINES - model name: NB - selection option: random-projection
# performance: f1score 0.8131872249686927 - recall 0.8461226938238434 - Confusion matrix [[345.  88.]
#  [296. 266.]]
#
# BASELINES - model name: NB - selection option: recursive-feature-extraction
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# BASELINES - model name: NB - selection option: remove-low-var-features
# performance: f1score 0.8444875694229442 - recall 0.8736898052990009 - Confusion matrix [[349.  84.]
#  [278. 284.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: no-selection
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: pca
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: random-projection
# performance: f1score 0.9254271588635604 - recall 0.924203510410407 - Confusion matrix [[271. 162.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: SVM-l2 - selection option: remove-low-var-features
# performance: f1score 0.9227370136958939 - recall 0.9215885327954294 - Confusion matrix [[270. 163.]
#  [135. 427.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: no-selection
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: pca
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: random-projection
# performance: f1score 0.9226709868515455 - recall 0.92152578689935 - Confusion matrix [[271. 162.]
#  [136. 426.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: recursive-feature-extraction
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# LINEAR-MODELS - model name: LR-l2 - selection option: remove-low-var-features
# performance: f1score 0.9266346356875035 - recall 0.925386150673507 - Confusion matrix [[272. 161.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: no-selection
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: pca
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: random-projection
# performance: f1score 0.8882149602662145 - recall 0.8891725133104442 - Confusion matrix [[271. 162.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: recursive-feature-extraction
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-rbf - selection option: remove-low-var-features
# performance: f1score 0.9080911286653647 - recall 0.9090001579944108 - Confusion matrix [[277. 156.]
#  [155. 407.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: no-selection
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: pca
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: random-projection
# performance: f1score 0.5262046633161075 - recall 0.6594398683479143 - Confusion matrix [[ 21. 412.]
#  [ 34. 528.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: recursive-feature-extraction
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: SVM-poly - selection option: remove-low-var-features
# performance: f1score 0.5923755044903279 - recall 0.689762647952303 - Confusion matrix [[ 47. 386.]
#  [ 42. 520.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: no-selection
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: pca
# performance: f1score 0.7336511707673248 - recall 0.7350368341747652 - Confusion matrix [[227. 206.]
#  [236. 326.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: random-projection
# performance: f1score 0.7885470982766289 - recall 0.7894927975387745 - Confusion matrix [[241. 192.]
#  [209. 353.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: recursive-feature-extraction
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-gini - selection option: remove-low-var-features
# performance: f1score 0.7486695893231335 - recall 0.7507691861140137 - Confusion matrix [[232. 201.]
#  [230. 332.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: no-selection
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: pca
# performance: f1score 0.732295181974822 - recall 0.7328071300772451 - Confusion matrix [[217. 216.]
#  [225. 337.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: random-projection
# performance: f1score 0.7653133452504477 - recall 0.7671982338649004 - Confusion matrix [[223. 210.]
#  [206. 356.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: DT-entropy - selection option: remove-low-var-features
# performance: f1score 0.7754086250530912 - recall 0.7762341585617447 - Confusion matrix [[237. 196.]
#  [214. 348.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: no-selection
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: pca
# performance: f1score 0.8874656304534948 - recall 0.8858661878776822 - Confusion matrix [[246. 187.]
#  [134. 428.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: random-projection
# performance: f1score 0.8587846556064093 - recall 0.8588236848294318 - Confusion matrix [[250. 183.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-gini - selection option: remove-low-var-features
# performance: f1score 0.8630407490888757 - recall 0.8626344334677668 - Confusion matrix [[253. 180.]
#  [163. 399.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: no-selection
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: pca
# performance: f1score 0.8935366747709867 - recall 0.8919383883464342 - Confusion matrix [[253. 180.]
#  [138. 424.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: random-projection
# performance: f1score 0.8625150132118898 - recall 0.8620832179740227 - Confusion matrix [[251. 182.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-100-entropy - selection option: remove-low-var-features
# performance: f1score 0.8732119035743654 - recall 0.872571899152359 - Confusion matrix [[256. 177.]
#  [158. 404.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: no-selection
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: pca
# performance: f1score 0.8896393700430621 - recall 0.8881254866887051 - Confusion matrix [[242. 191.]
#  [127. 435.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: random-projection
# performance: f1score 0.8638244066872559 - recall 0.8639121840271266 - Confusion matrix [[252. 181.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: recursive-feature-extraction
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-gini - selection option: remove-low-var-features
# performance: f1score 0.8654988472835914 - recall 0.8650775841867796 - Confusion matrix [[253. 180.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: no-selection
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: pca
# performance: f1score 0.8968023944062731 - recall 0.8951081964012998 - Confusion matrix [[253. 180.]
#  [135. 427.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: random-projection
# performance: f1score 0.8702325303864322 - recall 0.8699066791020814 - Confusion matrix [[252. 181.]
#  [156. 406.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: recursive-feature-extraction
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: RF-250-entropy - selection option: remove-low-var-features
# performance: f1score 0.8699292833104554 - recall 0.8693537518250162 - Confusion matrix [[256. 177.]
#  [161. 401.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: no-selection
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: pca
# performance: f1score 0.8033131808897132 - recall 0.8038674660801096 - Confusion matrix [[236. 197.]
#  [191. 371.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: random-projection
# performance: f1score 0.8046287871399934 - recall 0.8051216397480766 - Confusion matrix [[241. 192.]
#  [196. 366.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: recursive-feature-extraction
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-64 - selection option: remove-low-var-features
# performance: f1score 0.8321791826299592 - recall 0.8318999061815154 - Confusion matrix [[245. 188.]
#  [178. 384.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: no-selection
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: pca
# performance: f1score 0.8317381968155039 - recall 0.8328289367082471 - Confusion matrix [[256. 177.]
#  [192. 370.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: random-projection
# performance: f1score 0.8121774040954888 - recall 0.8146762720038582 - Confusion matrix [[246. 187.]
#  [195. 367.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: recursive-feature-extraction
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]
#
# NON-LINEAR-MODELS - model name: MLP-128 - selection option: remove-low-var-features
# performance: f1score 0.845508414263744 - recall 0.846270959776707 - Confusion matrix [[242. 191.]
#  [164. 398.]]

# %% [markdown]
# ### F.2) Saving the best candidate's configuration
#
# And now we save the best candidate's (the model with highest score) details to a local file: its name, its validation score in the selection epxeriment, its parameters, and the used data transformer if any reduction technique was applied to data before hitting the model during learning.
#
# The used normalizer was saved before to a local file, since the step: normalization of learning data. (see previous paragraphs)

# %%
sorted_history = sorted(history, key=lambda x: x['f1-score'], reverse=True)
best_cofnig = sorted_history[0]
best_config_filename = "config.save"
print(best_cofnig)
joblib.dump(best_cofnig, output_directory + '/' + best_config_filename)
# Out:
# {'family': 'LINEAR-MODELS', 'name': 'LR-l2', 'select_option': 'random-projection', 'f1-score': 0.927709494613406, 'recall': 0.9263598417334049, 'confusion': array([[271., 162.],
#        [132., 430.]]), 'k': 12, 't': 0.025, 'learn_time': 0.1635119915008545, 'transformer': GaussianRandomProjection(n_components=12, random_state=1)}
# ['../resources/model_development_std_medium_remparents/config.save']

# %% [markdown]
# # Actual training of the best model
#
# We reload configuration files of the previously selected model, and we proceed to actual training of an instance of it, always on $D_{learn}$. We reuse the same normalization / reduction pipeline, saved from the selection loop within the configuration file. The final trained classification model's checkpoint is saved to a local file for later use in inference.

# %%
best_config = joblib.load(output_directory + '/' + best_config_filename)
transformer = best_config["transformer"]
if best_config['select_option'] != "no-selection":
    Xlearn_featurized = transformer.fit_transform(Xlearn_normalized, Ylearn)
    model_input = Xlearn_featurized
else:
    model_input = Xlearn_normalized
transformer_filename = "transformer.save"
joblib.dump(transformer, output_directory + '/' + transformer_filename) 
best_model_instance = list(list(filter(lambda m: list(m.keys())[0]==best_config["name"], candidate_models[best_config["family"]]))[0].values())[0]
best_model_instance.fit(model_input, Ylearn)
best_model_filename = "checkpoint.save"
joblib.dump(best_model_instance, output_directory + '/' + best_model_filename)
# Out:
# ['../resources/model_development_std_medium_remparents/checkpoint.save']

# %% [markdown]
# # Prediction using the pre-trained best model
#
# From previously saved local files, we reload:
#
# - The normalizer that was computed earlier on learning data samples.
# - The best configuration file, containing the eventual transformation (reduction method) used along with the best classification model during selection process.
# - The best classification model's checkpoint
#
# Finally, we infer labels on data points from $D_{test}$, which were never seen by the chosen classification model before, neither during selection nor during the actual training, and evaluate obtained prediction against real ones using the macro-avg f1 score.
#
# Again, we make sure to re-apply the same pre-processing (normalization, eventual dim. reduction) pipeline used in selection process to $D_{test}$ data before it hits the model.

# %%
normalizer = joblib.load(output_directory + '/' + normalizer_filename) 
transformer = joblib.load(output_directory + '/' + transformer_filename) 
best_model_instance = joblib.load(output_directory + '/' + best_model_filename) 
best_config = joblib.load(output_directory + '/' + best_config_filename) 
Xtest_normalized = normalizer.transform(Xtest)
if best_config['select_option'] != "no-selection":
    Xtest_featurized = transformer.transform(Xtest_normalized)
    model_input = Xtest_featurized
else:
    model_input = Xtest_normalized
predicted_test_labels = best_model_instance.predict(model_input)
test_confusion_mat = confusion_matrix(Ytest, predicted_test_labels)
test_recall = recall_score(Ytest, predicted_test_labels, average="macro")
test_f1 = f1_score(Ytest, predicted_test_labels, average="macro")
print(Counter(Ytest))
print(Counter(predicted_test_labels))
print(test_recall)
print(test_confusion_mat)
print(test_f1)
# Out:
# Counter({1.0: 99, 0.0: 76})
# Counter({1.0: 99, 0.0: 76})
# 0.6976342371079214
# [[50 26]
#  [26 73]]
# 0.6976342371079214

# %% [markdown]
# # Final comments
